# %% [markdown]
# <a href="https://colab.research.google.com/github/saikrish02/Integrated-Traffic-Signal-Control-System/blob/main/Yolov5_Detectionipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/gdrive', force_remount=True)
# Out:
# Mounted at /gdrive

# %%
# %cd /gdrive/MyDrive
# Out:
# /gdrive/MyDrive

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 645.7/645.7 kB 10.6 MB/s eta 0:00:00
# ...

# %%
# !unzip /gdrive/MyDrive/finalDataset3.zip -d /content/data1
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/data1/finalDataset3/train/labels/truck-715-_jpg.rf.2b7a1e7efee0681d302a5c5a6580ef6e.txt
#   inflating: /content/data1/finalDataset3/train/labels/truck-715-_jpg.rf.af869a65ebe6315f7c0c8d0ec1905585.txt
#   inflating: /content/data1/finalDataset3/train/labels/truck-715-_jpg.rf.bf7a72fefa806a1a3e373170f5ce46dd.txt
#   inflating: /content/data1/finalDataset3/train/labels/truck-716-_jpg.rf.4f5678d8409a7b7eb1ac029ddd0958d6.txt
#   inflating: /content/data1/finalDataset3/train/labels/truck-716-_jpg.rf.7f1cf64734a3fb911e4538867ddec3d1.txt
#   inflating: /content/data1/finalDataset3/train/labels/truck-716-_jpg.rf.94fdca27936af3215b2bab2d605ee799.txt
#   inflating: /content/data1/finalDataset3/train/labels/truck-716-_jpg.rf.b11ad6d2cccae1c80a645be052651f1a.txt
#   inflating: /content/data1/finalDataset3/train/labels/truck-717-_jpg.rf.663c8f0e877225da9ec1d15bcb995484.txt
# ...

# %%
# !pip install wandb
import wandb
# !wandb login --relogin
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 8.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.0/190.0 kB 12.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.8/224.8 kB 11.8 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.3 MB/s eta 0:00:00
# ...
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8791 sha256=b8abc41e37484bd999bc68701b0422fc24b6032e330dde002640c635345a911d
#   Stored in directory: /root/.cache/pip/wheels/e7/f3/22/152153d6eb222ee7a56ff8617d80ee5207207a8c00a7aab794
# Successfully built pathtools
# ...
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# ...

# %%
wandb.init(project="yolov8n")
# Out:
# wandb: Currently logged in as: saikrish02 (saikrishna02). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.15.11
# Run data is saved locally in <code>/gdrive/MyDrive/wandb/run-20230922_155622-4bojsqqp</code>
# Syncing run <strong><a href='https://wandb.ai/saikrishna02/yolov8n/runs/4bojsqqp' target="_blank">rose-plant-1</a></strong> to <a href='https://wandb.ai/saikrishna02/yolov8n' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/saikrishna02/yolov8n' target="_blank">https://wandb.ai/saikrishna02/yolov8n</a>
#  View run at <a href='https://wandb.ai/saikrishna02/yolov8n/runs/4bojsqqp' target="_blank">https://wandb.ai/saikrishna02/yolov8n/runs/4bojsqqp</a>
# ...

# %%
# !pip install clearml
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 14.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pyjwt
#     Found existing installation: PyJWT 2.3.0
#     Uninstalling PyJWT-2.3.0:
#       Successfully uninstalled PyJWT-2.3.0
# ...

# %%
# !clearml-init
# Out:
# ClearML SDK setup process
#
# Please create new clearml credentials through the settings page in your `clearml-server` web app (e.g. http://localhost:8080//settings/workspace-configuration)
# Or create a free account at https://app.clear.ml/settings/workspace-configuration
#
# In settings page, press "Create new credentials", then press "Copy to clipboard".
#
# Paste copied configuration here:
# api {   # R Sai Krishna's workspace   web_server: https://app.clear.ml   api_server: https://api.clear.ml   files_server: https://files.clear.ml   credentials {     "access_key" = "GLBGU3ZXYFOSPCMQ3YFK"     "secret_key" = "JeeebrtNJ7ysZ4fvamDRIBzLcWpQUf5cnP5HYr4ZHsqOpuaScy"   } }
# Detected credentials key="GLBGU3ZXYFOSPCMQ3YFK" secret="Jeee***"
#
# ClearML Hosts configuration:
# Web App: https://app.clear.ml
# API: https://api.clear.ml
# File Store: https://files.clear.ml
#
# Verifying credentials ...
# Credentials verified!
#
# New configuration stored in /root/clearml.conf
# ...

# %%
# !yolo task=detect mode=train model=yolov8m.pt data=/content/data1/finalDataset3/data.yaml epochs=100 imgsz=640 batch=32
# Out:
# Ultralytics YOLOv8.0.184 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=train model=/gdrive/MyDrive/last2.pt data=/content/data1/finalDataset3/data.yaml epochs=100 imgsz=640 batch=32 resume=True
# Out:
# Ultralytics YOLOv8.0.184 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=train model=/gdrive/MyDrive/last.pt data=/content/data1/finalDataset3/data.yaml epochs=100 imgsz=640 batch=32 resume=True
# Out:
# Ultralytics YOLOv8.0.184 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=train model=/gdrive/MyDrive/last.pt data=/content/data1/finalDataset3/data.yaml epochs=100 imgsz=640 batch=32 resume=True
# Out:
# Ultralytics YOLOv8.0.186 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=train model=/gdrive/MyDrive/last.pt data=/content/data1/finalDataset3/data.yaml epochs=100 imgsz=640 batch=32 resume=True
# Out:
# Ultralytics YOLOv8.0.187 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=val model=/gdrive/MyDrive/runs/detect/train4/weights/best.pt data=/content/data1/finalDataset3/data.yaml
# Out:
# Ultralytics YOLOv8.0.216 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25843813 parameters, 0 gradients, 78.7 GFLOPs
# ...
# 100% 755k/755k [00:00<00:00, 15.2MB/s]
# val: Scanning /content/data1/finalDataset3/valid/labels... 2258 images, 0 backgrounds, 0 corrupt: 100% 2258/2258 [00:01<00:00, 1901.47it/s]
# val: WARNING ⚠️ /content/data1/finalDataset3/valid/images/truck-453-_jpg.rf.e42b7a1d1d442a02f2fbe29f254ad6cf.jpg: 1 duplicate labels removed
# val: New cache created: /content/data1/finalDataset3/valid/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 142/142 [02:11<00:00,  1.08it/s]
#                    all       2258       9918      0.871      0.793      0.862      0.644
#                   auto       2258       1551       0.91       0.81       0.89      0.658
#                    bus       2258       1246      0.889      0.827      0.894      0.693
# ...
