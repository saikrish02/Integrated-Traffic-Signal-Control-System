# %% [markdown]
# <a href="https://colab.research.google.com/github/saikrish02/Integrated-Traffic-Signal-Control-System/blob/main/YOLOV8_object_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/gdrive', force_remount=True)
# Out:
# Mounted at /gdrive

# %%
# %cd /gdrive/MyDrive
# Out:
# /gdrive/MyDrive

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 609.5/609.5 kB 10.1 MB/s eta 0:00:00
# ...

# %%
import torch
import os
from IPython.display import Image, clear_output  # to display images

print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Setup complete. Using torch 2.0.1+cu118 (Tesla T4)

# %%
# !yolo task=detect mode=train model=yolov8x.pt data=/gdrive/MyDrive/dataset/dataset/data.yaml epochs=100 batch=16 imgsz=640 cache=True
# Out:
# Ultralytics YOLOv8.0.159 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !unzip /gdrive/MyDrive/dataset.zip -d /content/data
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/data/Vehicle and License Plate Dataset with YOLOv5 Annotations/train/labels/5499.txt
#   inflating: /content/data/Vehicle and License Plate Dataset with YOLOv5 Annotations/train/labels/55.txt
#   inflating: /content/data/Vehicle and License Plate Dataset with YOLOv5 Annotations/train/labels/550.txt
#   inflating: /content/data/Vehicle and License Plate Dataset with YOLOv5 Annotations/train/labels/5500.txt
#   inflating: /content/data/Vehicle and License Plate Dataset with YOLOv5 Annotations/train/labels/5501.txt
#   inflating: /content/data/Vehicle and License Plate Dataset with YOLOv5 Annotations/train/labels/5502.txt
#   inflating: /content/data/Vehicle and License Plate Dataset with YOLOv5 Annotations/train/labels/5503.txt
#   inflating: /content/data/Vehicle and License Plate Dataset with YOLOv5 Annotations/train/labels/5504.txt
# ...

# %%
# !yolo task=detect mode=train model=/gdrive/MyDrive/last.pt data=/content/data/dataset/data.yaml epochs=100 batch=16 imgsz=640 resume=True
# Out:
# Ultralytics YOLOv8.0.160 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=train model=/gdrive/MyDrive/last.pt data=/content/data/dataset/data.yaml epochs=100 batch=16 imgsz=640 resume=True cache=True
# Out:
# Ultralytics YOLOv8.0.161 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=train model=/gdrive/MyDrive/runs/detect/train2/weights/last.pt data=/content/data/dataset/data.yaml epochs=100 batch=16 imgsz=640 resume=True cache=True
# Out:
# Ultralytics YOLOv8.0.162 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=train model=/gdrive/MyDrive/runs/detect/train2/weights/last.pt data=/content/data/dataset/data.yaml epochs=100 batch=16 imgsz=640 resume=True cache=True
# Out:
# Ultralytics YOLOv8.0.162 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# %cd /gdrive/MyDrive
# Out:
# [Errno 2] No such file or directory: '/gdrive/MyDrive'
# /content

# %%
# !yolo task=detect mode=predict model='/gdrive/MyDrive/runs/detect/train2/weights/best.pt' source='/content/test.jpeg' imgsz=640 conf=0.1 classes=[0]
# Out:
# /bin/bash: line 1: yolo: command not found

# %%
from ultralytics import YOLO

model = YOLO('best.pt')

# Define path to the image file
source = '/content/1.jpg'

# Run inference on the source
results = model(source)  # list of Results objects
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-349beec93465> in <cell line: 3>()
#       1 from ultralytics import YOLO
#       2
# ----> 3 model = YOLO('best.pt')
#       4
#       5 # Define path to the image file
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/engine/model.py in __init__(self, model, task)
#      92             self._new(model, task)
#      93         else:
# ---> 94             self._load(model, task)
#      95
#      96     def __call__(self, source=None, stream=False, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/engine/model.py in _load(self, weights, task)
#     138         suffix = Path(weights).suffix
#     139         if suffix == '.pt':
# --> 140             self.model, self.ckpt = attempt_load_one_weight(weights)
#     141             self.task = self.model.args['task']
# ...
