# %% [markdown]
# <a href="https://colab.research.google.com/github/saikrish02/Integrated-Traffic-Signal-Control-System/blob/main/helmetDetection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/gdrive', force_remount=True)
# Out:
# Mounted at /gdrive

# %%
# %cd /gdrive/MyDrive
# Out:
# /gdrive/My Drive

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 721.3/721.3 kB 10.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 48.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 58.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 59.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 10.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 8.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 6.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 7.1 MB/s eta 0:00:00
# ...

# %%
# !unzip /gdrive/MyDrive/HelmetDataset.zip -d /content/data
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: /content/data/train/labels/Test-helmmet-15-_jpg.rf.dc24570bc58ea2a397ed12a552b82f89.txt
#  extracting: /content/data/train/labels/Test-helmmet-16-_jpg.rf.856c6e598db4f1c4c842b9aebdcc5649.txt
#  extracting: /content/data/train/labels/Test-helmmet-16-_jpg.rf.c8138e609bc20da854b79732fd8288d6.txt
#  extracting: /content/data/train/labels/Test-helmmet-17-_jpg.rf.1d3b0631c0b1f02840ae77617296b6e9.txt
#  extracting: /content/data/train/labels/Test-helmmet-17-_jpg.rf.e90f92ee4dbf907f72c89bee0afba2f7.txt
#  extracting: /content/data/train/labels/Test-helmmet-19-_jpg.rf.1eabee98c252db065d0f8ed199cc21d5.txt
#  extracting: /content/data/train/labels/Test-helmmet-2-_jpg.rf.9dd7032e9149020ecb7e0ccca44e6d88.txt
#  extracting: /content/data/train/labels/Test-helmmet-2-_jpg.rf.b61aa56c77658832e619c27b3c4b2b6c.txt
#  extracting: /content/data/train/labels/Test-helmmet-20-_jpg.rf.00a94dc6f97d5ead01496f45052abdea.txt
# ...

# %%
# !pip install wandb
import wandb
# !wandb login
wandb.init(project="helmet-detection")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 25.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.4/195.4 kB 23.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.5/258.5 kB 18.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 9.3 MB/s eta 0:00:00
# ...
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: rskjntu2002 (rskjntu). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.16.3
# Run data is saved locally in <code>/gdrive/MyDrive/wandb/run-20240227_120858-ag290izy</code>
# ...

# %%
# !yolo task=detect mode=train epochs=100 batch=16 imgsz=640 model=yolov8x.pt data=/content/data/data.yaml
# Out:
# Ultralytics YOLOv8.1.16 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=train epochs=100 batch=16 imgsz=640 resume=True model=/gdrive/MyDrive/runs/detect/train3/weights/last.pt data=/content/data/data.yaml
# Out:
# Ultralytics YOLOv8.1.18 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=train epochs=100 batch=16 imgsz=640 resume=True model=/gdrive/MyDrive/runs/detect/train3/weights/last.pt data=/content/data/data.yaml
# Out:
# Ultralytics YOLOv8.1.18 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=train epochs=100 batch=16 imgsz=640 resume=True model=/gdrive/MyDrive/runs/detect/train3/weights/last.pt data=/content/data/data.yaml
# Out:
# Ultralytics YOLOv8.1.19 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo val model=/gdrive/MyDrive/runs/detect/train3/weights/best.pt data=/content/data/data.yaml imgsz=640 batch=16
# Out:
# Ultralytics YOLOv8.1.29 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 268 layers, 68125494 parameters, 0 gradients, 257.4 GFLOPs
# ...
# 100% 755k/755k [00:00<00:00, 24.7MB/s]
# val: Scanning /content/data/valid/labels... 920 images, 0 backgrounds, 0 corrupt: 100% 920/920 [00:00<00:00, 2206.01it/s]
# val: WARNING ⚠️ /content/data/valid/images/train-helmet-8-_jpg.rf.669793e3ddaa144150a18b0a0a612210.jpg: 3 duplicate labels removed
# val: New cache created: /content/data/valid/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 58/58 [00:57<00:00,  1.01it/s]
#                    all        920       1091      0.953       0.95      0.982      0.809
#              No-Helmet        920        623      0.964       0.95      0.987      0.816
#                   Safe        920        468      0.943       0.95      0.977      0.802
# ...

# %%
from ultralytics import YOLO

model = YOLO('/gdrive/MyDrive/runs/detect/train3/weights/best.pt')
results = model('/content/helmet12.jpeg', save=True)
# Out:
# image 1/1 /content/helmet12.jpeg: 480x640 3 Safes, 72.5ms
# Speed: 3.1ms preprocess, 72.5ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs/detect/predict5
