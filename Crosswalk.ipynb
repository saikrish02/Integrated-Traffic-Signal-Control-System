# %% [markdown]
# <a href="https://colab.research.google.com/github/saikrish02/Integrated-Traffic-Signal-Control-System/blob/main/Crosswalk.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/gdrive', force_remount=True)
# Out:
# Mounted at /gdrive

# %%
# %cd /gdrive/MyDrive
# Out:
# /gdrive/MyDrive

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 716.2/716.2 kB 10.0 MB/s eta 0:00:00
# ...

# %%
# !unzip /gdrive/MyDrive/crosswalk.zip -d /content/data
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: /content/data/train/images/02_0036_filename4563_jpg.rf.5e087b8ca6f7c2fd6b2e6c0dfbfc68aa.jpg
#  extracting: /content/data/train/images/02_0036_filename4564_jpg.rf.cc8d9e5068f830a5b57f6455aaedd93c.jpg
#  extracting: /content/data/train/images/02_0036_filename4565_jpg.rf.910419cff0afda097c5673d2df7c5bdd.jpg
#  extracting: /content/data/train/images/02_0036_filename4566_jpg.rf.8627644306e69ed363578cbbcf476d5d.jpg
#  extracting: /content/data/train/images/02_0036_filename4567_jpg.rf.38bafad2c2fb62277cfe4e1fcc470cb7.jpg
#  extracting: /content/data/train/images/02_0036_filename4569_jpg.rf.e6a0e28a10ee001a6a2906c0b24db076.jpg
#  extracting: /content/data/train/images/02_0036_filename4570_jpg.rf.ab30d76c8058faf12520975055b87b7b.jpg
#  extracting: /content/data/train/images/02_0036_filename4582_jpg.rf.c57620c92872999ea0906883d6810d9e.jpg
# ...

# %%
# !pip install wandb
import wandb
# !wandb login
wandb.init(project="crosswalk-detection")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 12.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.4/195.4 kB 17.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.5/258.5 kB 16.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 9.5 MB/s eta 0:00:00
# ...
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: rskjntu2002 (rskjntu). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.16.3
# Run data is saved locally in <code>/gdrive/MyDrive/wandb/run-20240227_051113-2osmrfr0</code>
# ...

# %%
# !yolo task=detect mode=train epochs=100 batch=16 imgsz=640 model=yolov8x.pt data=/content/data/data.yaml
# Out:
# Ultralytics YOLOv8.1.19 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
