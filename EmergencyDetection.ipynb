# %% [markdown]
# <a href="https://colab.research.google.com/github/saikrish02/Integrated-Traffic-Signal-Control-System/blob/main/EmergencyDetection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/gdrive', force_remount=True)
# Out:
# Mounted at /gdrive

# %%
# %cd /gdrive/MyDrive
# Out:
# /gdrive/MyDrive

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 715.4/715.4 kB 9.4 MB/s eta 0:00:00
# ...

# %%
# !unzip /gdrive/MyDrive/emergency.zip -d /content/data
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: /content/data/train/labels/RCFYVJWTWCGG_jpg.rf.8ff79950e4b2d869baffdd28494b89c6.txt
#  extracting: /content/data/train/labels/RCPQ1PEED7YU_jpg.rf.3ab1e702c10243d496c160fdb37d6883.txt
#  extracting: /content/data/train/labels/RCPQ1PEED7YU_jpg.rf.47ddeacf42e821eeec4485d21074754b.txt
#  extracting: /content/data/train/labels/RCQ7M2TX90HH_jpg.rf.61725dda37d8e95f7ad08f6f4b2ce079.txt
#  extracting: /content/data/train/labels/RCQ7M2TX90HH_jpg.rf.6617ba78cd2af05363f3e8243332e663.txt
#  extracting: /content/data/train/labels/RCQ7M2TX90HH_jpg.rf.b2b909e1bf633873dd8ba71e8372d897.txt
#  extracting: /content/data/train/labels/RCQ7M2TX90HH_jpg.rf.ce89a92ab174133200f3a90e930c5d30.txt
#  extracting: /content/data/train/labels/RCYSB7YXQM01_jpg.rf.d5b2669cb000fc1f557d7419b2849d8d.txt
#  extracting: /content/data/train/labels/RCYSB7YXQM01_jpg.rf.ee406fcfda50534571143a4de75e71a5.txt
# ...

# %%
# !pip install wandb
import wandb
# !wandb login
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 18.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.4/195.4 kB 23.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.5/258.5 kB 20.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 9.4 MB/s eta 0:00:00
# ...
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %%
# !yolo task=detect mode=train epochs=100 batch=16 imgsz=640 model=yolov8x.pt data=/content/data/data.yaml
# Out:
# Ultralytics YOLOv8.1.9 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=train epochs=100 batch=16 imgsz=640 resume=True model=/gdrive/MyDrive/runs/detect/train2/weights/last.pt data=/content/data/data.yaml
# Out:
# Ultralytics YOLOv8.1.9 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=train epochs=100 batch=16 imgsz=640 resume=True model=/gdrive/MyDrive/runs/detect/train2/weights/last.pt data=/content/data/data.yaml
# Out:
# Ultralytics YOLOv8.1.12 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=train epochs=100 batch=16 imgsz=640 resume=True model=/gdrive/MyDrive/runs/detect/train2/weights/last.pt data=/content/data/data.yaml
# Out:
# Ultralytics YOLOv8.1.14 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=train epochs=100 batch=16 imgsz=640 resume=True model=/gdrive/MyDrive/runs/detect/train2/weights/last.pt data=/content/data/data.yaml
# Out:
# Ultralytics YOLOv8.1.14 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=train epochs=100 batch=16 imgsz=640 resume=True model=/gdrive/MyDrive/runs/detect/train2/weights/last.pt data=/content/data/data.yaml
# Out:
# Ultralytics YOLOv8.1.14 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=train epochs=100 batch=16 imgsz=640 resume=True model=/gdrive/MyDrive/runs/detect/train2/weights/last.pt data=/content/data/data.yaml
# Out:
# Ultralytics YOLOv8.1.15 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=train epochs=100 batch=16 imgsz=640 resume=True model=/gdrive/MyDrive/runs/detect/train2/weights/last.pt data=/content/data/data.yaml
# Out:
# Ultralytics YOLOv8.1.16 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
