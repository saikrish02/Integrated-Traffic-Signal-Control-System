# %% [markdown]
# <a href="https://colab.research.google.com/github/saikrish02/Integrated-Traffic-Signal-Control-System/blob/main/Accident_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/gdrive', force_remount=True)
# Out:
# Mounted at /gdrive

# %%
# %cd /gdrive/MyDrive
# Out:
# /gdrive/MyDrive

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 710.2/710.2 kB 8.9 MB/s eta 0:00:00
# ...

# %%
# !unzip /gdrive/MyDrive/accident.zip -d /content/accident1
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: /content/accident1/train/images/images_534-2-_jpg.rf.a8687e89b78dfd1b506c3255ff2cae4f.jpg
#  extracting: /content/accident1/train/images/images_534-2-_jpg.rf.b39e1b1bd6c292deb06ec81ed7a15821.jpg
#  extracting: /content/accident1/train/images/images_534_jpg.rf.2456447a60ce8142564cb0d44db79150.jpg
#  extracting: /content/accident1/train/images/images_534_jpg.rf.4afb223c5a6436c697416518abed03de.jpg
#  extracting: /content/accident1/train/images/images_534_jpg.rf.de942a3615e50f99bbc8042fce35677f.jpg
#  extracting: /content/accident1/train/images/images_537-2-_jpg.rf.2796e585330250e4e279a3c4c06d0e34.jpg
#  extracting: /content/accident1/train/images/images_537-2-_jpg.rf.6900e4bc4d9ac888e3411ddb5a080b4f.jpg
#  extracting: /content/accident1/train/images/images_537-2-_jpg.rf.f69debcd02aea01ed7bf8e9350e246ea.jpg
#  extracting: /content/accident1/train/images/images_538_jpg.rf.0d7dd592ca62e73bf255167d3918c0ac.jpg
# ...

# %%
# !pip install wandb
import wandb
# !wandb login
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 27.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.4/196.4 kB 25.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 257.8/257.8 kB 25.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 10.4 MB/s eta 0:00:00
# ...
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %%
# !yolo task=detect mode=train epochs=100 batch=16 imgsz=640 model=yolov8x.pt data=/content/accident1/data.yaml optimizer='SGD'
# Out:
# Ultralytics YOLOv8.1.8 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=train epochs=100 batch=16 imgsz=640 model=yolov8x.pt data=/content/accident1/data.yaml
# Out:
# Ultralytics YOLOv8.1.9 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=train epochs=100 batch=16 imgsz=640 resume=True model=/gdrive/MyDrive/runs/detect/train3/weights/last.pt data=/content/accident1/data.yaml
# Out:
# Ultralytics YOLOv8.1.9 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=train epochs=100 batch=16 imgsz=640 resume=True model=/gdrive/MyDrive/runs/detect/train3/weights/last.pt data=/content/accident1/data.yaml
# Out:
# Ultralytics YOLOv8.1.12 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
